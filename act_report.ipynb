# %% [markdown]
# # ACT REPORT

# %% [markdown]
# ### INSIGHTS

# %% [markdown]
# 1. The scatter plot below shows that there is a positive relationship/correlation between retweets and Likes. Also the Pearson's coefficient is 0.86 which is close to 1(positive correlation). As any tweet, Tweeted by WeRateDogs gets retweeted, there is a likely increase in number of Likes. Note that this correlation does not imply causability.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2.The average likes gotten by dog(s) in doggo, puppo stage is about 40 thousand likes
# The bar chart shows that the @ WeRateDogs audience  likes Doggo and Puppo dogs much more than any. If @WerateDogs is trying to garner engagements on his tweets, he should post more on doggo and puppo dogs to garner more likes

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# 3. The lowest average retweets gotten is by dogs in pupper stage which is approximately 2,000 Retweets.
# And the highest average retweets is by dogs in doggo,puppo stage at approximately 16,000 Retweets
# The bar chart shows that the audience retweets Doggo and Pupper dogs much more than any dog. If an audience likes a dog, they are more likely to retweet that tweet. If @WerateDogs is trying to garner engagements on his tweets, he should post more on doggo and puppo dogs.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# 4. A large population of tweets tweeted by @WeRateDogs was made on an Iphone.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# 5. The bar chart shows the average likes of tweets by tweet source. it is likely that tweeting from an Iphone gathers more likes, but it is worthy to note that there are other factors that could be at play such as contents of the tweet, the dog_stage as well.

# %% [markdown]
# ![download.png](attachment:download.png)

# %% [markdown]
# ## Limitations to my analysis

# %% [markdown]
#  1. I was unable to retrieve the tweet status of about 29 tweets while querying twitter ( I got the error could not retrieve status id)

# %% [markdown]
# 2.  Based on cleaning tweets that did not have a dog name, a particular souurce 'Vine - Make a Scene' was eliminated.
# so the analysis is representative of only a short samplle.

# %% [markdown]
# 3. I could only infer correlation and not causation between retweets and likes
